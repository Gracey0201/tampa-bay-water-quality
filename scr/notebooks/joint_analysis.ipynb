# %%
import os
print(os.getcwd())
# Out:
# /home/jupyteruser/scr/notebooks

# %%
import pandas as pd

# %%
import pandas as pd

# Water quality indices
df_results = pd.read_csv(
    "results/TAMPA_BAY_results_500.csv",
    parse_dates=["date"]
).set_index("date").sort_index()

df_rolling = pd.read_csv(
    "results/TAMPA_BAY_rolling_500.csv",
    parse_dates=["date"]
).set_index("date").sort_index()

monthly_avg = pd.read_csv(
    "results/TAMPA_BAY_monthly_500.csv",
    index_col=0
)

# Environmental variables (Kalu)
env = pd.read_csv(
    "results/env_data.csv",
    parse_dates=["date"]
).set_index("date").sort_index()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pandas as pd
#       3 # Water quality indices
# ----> 4 df_results = pd.read_csv(
#       5     "results/TAMPA_BAY_results_500.csv",
#       6     parse_dates=["date"]
#       7 ).set_index("date").sort_index()
#       9 df_rolling = pd.read_csv(
#      10     "results/TAMPA_BAY_rolling_500.csv",
#      11     parse_dates=["date"]
#      12 ).set_index("date").sort_index()
#      14 monthly_avg = pd.read_csv(
#      15     "results/TAMPA_BAY_monthly_500.csv",
#      16     index_col=0
#      17 )
#
# ...

# %%
import pandas as pd

df_results  = pd.read_csv("home/jupyteruser/results/TAMPA_BAY_results_500.csv", parse_dates=["date"])
df_rolling  = pd.read_csv("home/jupyteruser/results/TAMPA_BAY_rolling_500.csv", parse_dates=["date"])
monthly_avg = pd.read_csv("home/jupyteruser/results/TAMPA_BAY_montly_csv_500.csv", index_col=0)
env         = pd.read_csv("home/jupyteruser/results/env_data_csv.csv", parse_dates=["date"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 import pandas as pd
# ----> 3 df_results  = pd.read_csv("home/jupyteruser/results/TAMPA_BAY_results_500.csv", parse_dates=["date"])
#       4 df_rolling  = pd.read_csv("home/jupyteruser/results/TAMPA_BAY_rolling_500.csv", parse_dates=["date"])
#       5 monthly_avg = pd.read_csv("home/jupyteruser/results/TAMPA_BAY_montly_csv_500.csv", index_col=0)
#
# ...

# %%
import os
print(os.getcwd())
# Out:
# /home/jupyteruser/scr/notebooks
